# %% [markdown]
# <a href="https://colab.research.google.com/github/nistha2807/SD_nistha_0096/blob/main/PRE_PROJECT_ATM_SIMULATOR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def wid():
  amount = int(input("Enter Amount: "))


  if amount <= 0:
    print("Invalid Amount")

  elif amount > accounts[card]["balance"]:
    print("Insufficient Funds")
    print("Balance:", accounts[card]["balance"])

  else:
    atm_cash = 50000

  if amount > atm_cash:
    print("ATM Out of Cash")

  else:
    accounts[card]["balance"] -= amount
    print("Please Collect Your Cash")
    print("Updated Balance:", accounts[card]["balance"])
def dep():
  amount = int(input("Enter Deposit Amount: "))

  if amount <= 0:
    print("Invalid Amount")

  else:
    accounts[card]["balance"] += amount
    print("Deposit Successful")
    print("Updated Balance:", accounts[card]["balance"])
def bal():
  print("Current Balance:", accounts[card]["balance"])


accounts = {
    "1234567890": {"pin": "1234", "balance": 5000},
    "9876543210": {"pin": "4321", "balance": 10000}
}

card = input("Enter Card Number: ")

if card in accounts:
    pin = input("Enter PIN: ")

    if pin == accounts[card]["pin"]:

        while True:
            print("\n----- ATM MENU -----")
            print("1. Withdraw")
            print("2. Deposit")
            print("3. Balance Inquiry")
            print("4. Exit")

            choice = input("Enter your choice: ")
            if choice == "1":
                wid()
            elif choice == "2":
                dep()
            elif choice == "3":
                bal()
            elif choice == "4":
                print("Card Ejected")
                print("Thank You!")
                break

            else:
                print("Invalid Choice")

            receipt = input("Print Receipt? (y/n): ")
            if receipt.lower() == "y":
                print("----- RECEIPT -----")
                print("Balance:", accounts[card]["balance"])

            again = input("Another Transaction? (y/n): ")
            if again.lower() != "y":
                print("Card Ejected")
                print("Thank You!")
                break

    else:
        print("Incorrect PIN")
        print("Card Rejected")

else:
    print("Invalid Card Number")
# Out:
# Enter Card Number: 1234567890
# Enter PIN: 1234
#
# ----- ATM MENU -----
# 1. Withdraw
# 2. Deposit
# 3. Balance Inquiry
# 4. Exit
# Enter your choice: 2
# Enter Deposit Amount: 400
# Deposit Successful
# Updated Balance: 5400
# Print Receipt? (y/n): no
# Another Transaction? (y/n): no
# Card Ejected
# Thank You!

# %%
print("-----------Welcome to our Bank-----------\n")
print("----Please add your bank details to avail our services----\n")
name=str(input("Enter the name of your bank"))
print("----Please enter your card----")
print("----Please enter your pin----")
ac_num=int(input("Enter the Account Number\n"))

print("---Enter 1 to select Savings Account---\n")
print("---Enter 2 to select current account---\n")
print("---Enter 3 for other main type---\n")
print("---Enter 4 for other account type---\n")


ac_num2=(input("Choose the account type\n"))
def choice1(a):
  if a==1:
    print("redirecting to your savings account........\n")
  elif a==2:
    print("redirecting to  your current account.......\n")
  elif a==3:
    print("redirecting to your main account.......\n ")
  elif a==4:
    print("redirecting to......\n")
  else:
    print("!...Invalid Choice Selected...!\n")
choice1(ac_num2)

print("!..Please select any of the services to continue..!")
print("---Enter 1 for CASH WITHDRAWL---\n")
print("---Enter 2 for SEND MONEY---\n")
print("---Enter 3 for CHECK YOUR BALANCE---\n")
print("---Enter 4 for ADD MONEY---\n")

ac_num3=int(input("*....PLEASE ENTER THE SERVICE FROM ABOVE....*"))
def choice2(b):
  bankSummary=99999
  user=100000

  if b==1:

      ac_num3=int(input("ENTER THE AMOUNT FOR WITHDRAWL\n"))
      if b<bankSummary:
         print("-----ENTER THE PIN----\n")
         print("!...REMAINING BALANCE...!"+" " +str(bankSummary-ac_num3))
         print("PLEASE COLLECT THE CASH\n")
         user=user-ac_num3
      else:
         print("INSUFFICIENT BALANCE\n")
  elif ac_num2==2:
      ac_num4=int(input("ENTER THE AMOUNT TO SEND\n"))
      if ac_num4<userBalance:
         print("----TRANSACTION SUCCESSFULL\n")
      else:
         print("INSUFFICIENT BALANCE\n")

  elif ac_num2==3:
       print(userBalance)

  else:
    ac_num5=int(input("ENTER THE AMOUNT TO BE ADDED IN YOUR ACCOUNT\n"))
    user+=ac_num5
    print(userg)
choice2(ac_num3)



print("**......YOU HAVE SUCCESSFULLY COMPLETED YOUR TRANSACTION.....**")

# %%
print("-----------Welcome to our Bank-----------\n")
print("----Please add your bank details to avail our services----\n")
name=str(input("Enter the name of your bank"))
print("----Please enter your card----")
print("----Please enter your pin----")
ac_num=int(input("Enter the Account Number\n"))

print("---Enter 1 to select Savings Account---\n")
print("---Enter 2 to select current account---\n")
print("---Enter 3 for other main type---\n")
print("---Enter 4 for other account type---\n")


ac_num2=(input("Choose the account type\n"))
def choice1(a):
  if a==1:
    print("redirecting to your savings account........\n")
  elif a==2:
    print("redirecting to  your current account.......\n")
  elif a==3:
    print("redirecting to your main account.......\n ")
  elif a==4:
    print("redirecting to......\n")
  else:
    print("!...Invalid Choice Selected...!\n")
choice1(ac_num2)

print("!..Please select any of the services to continue..!")
print("---Enter 1 for CASH WITHDRAWL---\n")
print("---Enter 2 for SEND MONEY---\n")
print("---Enter 3 for CHECK YOUR BALANCE---\n")
print("---Enter 4 for ADD MONEY---\n")

ac_num3=int(input("*....PLEASE ENTER THE SERVICE FROM ABOVE....*"))
def choice2(b):
  bankSummary=99999
  user=100000

  if b==1:

      ac_num3=int(input("ENTER THE AMOUNT FOR WITHDRAWL\n"))
      if b<bankSummary:
         print("-----ENTER THE PIN----\n")
         print("!...REMAINING BALANCE...!"+" " +str(bankSummary-ac_num3))
         print("PLEASE COLLECT THE CASH\n")
         user=user-ac_num3
      else:
         print("INSUFFICIENT BALANCE\n")
  elif ac_num2==2:
      ac_num4=int(input("ENTER THE AMOUNT TO SEND\n"))
      if ac_num4<userBalance:
         print("----TRANSACTION SUCCESSFULL\n")
      else:
         print("INSUFFICIENT BALANCE\n")

  elif ac_num2==3:
       print(userBalance)

  else:
    ac_num5=int(input("ENTER THE AMOUNT TO BE ADDED IN YOUR ACCOUNT\n"))
    user+=ac_num5
    print(userg)
choice2(ac_num3)



print("**......YOU HAVE SUCCESSFULLY COMPLETED YOUR TRANSACTION.....**")
