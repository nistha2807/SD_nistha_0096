# %% [markdown]
# <a href="https://colab.research.google.com/github/nistha2807/SD_nistha_0096/blob/main/FUNCTION.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
l=(1,2,3,4,5,6,7,8,9)

# %%
l=[1,2,3,4,5]
l1=[]
for i in l:
  l1.append(1**2)

# %%
l=[1,2,3,4]

# %%
[i**2 for i in l]
# Out:
# [1, 4, 9, 16]

# %%
[i for i in l if i%2==0]
# Out:
# [2, 4]

# %%
l1=["sudha","skills","kumar","data science"]

# %%
l1
# Out:
# ['sudha', 'skills', 'kumar', 'data science']

# %%
[i.upper() for i in l1]
# Out:
# ['SUDHA', 'SKILLS', 'KUMAR', 'DATA SCIENCE']

# %%
d={"key1":1,"key2":2,"key3":3,"key4":4}

# %%
d
# Out:
# {'key1': 1, 'key2': 2, 'key3': 3, 'key4': 4}

# %%
{k:v**2 for k , v in d.items()}
# Out:
# {'key1': 1, 'key2': 4, 'key3': 9, 'key4': 16}

# %%
d.items()
# Out:
# dict_items([('key1', 1), ('key2', 2), ('key3', 3), ('key4', 4)])

# %%
d
# Out:
# {'key1': 1, 'key2': 2, 'key3': 3, 'key4': 4}

# %%
{k:v for k,v in d.items() if v>1}
# Out:
# {'key2': 2, 'key3': 3, 'key4': 4}

# %%
def add(a,b):
   return a+b
num1= int(input(" enter first number: "))
num2= int(input(" enter second number: "))
result= add(num1,num2)
print("sum=" , result)
# Out:
#  enter first number: 25
#  enter second number: 10
# sum= 35

# %%
def test1():
  return "nistha this side"

# %%
test1()
# Out:
# nistha this side

# %%
test1()+"sudh"
# Out:
# 'nistha this sidesudh'

# %%
def test2():
  return "this is my first return "

# %%
test2()
# Out:
# 'this is my first return '

# %%
test2() + "sudh"
# Out:
# 'this is my first return sudh'

# %%
def test3():
  return "sudh",23,345.45,[1,2,3]

# %%
test3()
# Out:
# ('sudh', 23, 35, 345.45, [1, 2, 3])

# %%
test3()
# Out:
# ('sudh', 23, 345.45, [1, 2, 3])

# %%
a,b,c,d = test3()

# %%
a
# Out:
# 'sudh'

# %%
b
# Out:
# 23

# %%
d
# Out:
# [1, 2, 3]

# %%
type(test3())
# Out:
# tuple

# %%
c
# Out:
# 345.45

# %%
a=1
b=4

# %%
a,b=1,4

# %%
def add():
  a=5+6/7
  return a

# %%
add()
# Out:
# 5.857142857142857

# %%
def test5(a,b,c):
  d= a+b/c
  return d

# %%
test5()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_4157/379652043.py in <cell line: 0>()
# ----> 1 test5()
#
# TypeError: test5() missing 3 required positional arguments: 'a', 'b', and 'c'

# %%
test5(4,5,6.78)
# Out:
# 4.737463126843657

# %%
test5(2,5,8)
# Out:
# 2.625

# %%
def test6(a,b):
  return a+b

# %%
test6(7,8)
# Out:
# 15

# %%
def test7(a,b):
    return a*b

# %%
test7(3,7)
# Out:
# 21

# %%
def test8(*args , a):
  return args , a

# %%
test8(1,2,3,4,a=3)
# Out:
# ((1, 2, 3, 4), 3)

# %%
def test9(c,d,a=23,b=1):
  return a,b,c,d

# %%
test9(3,4)
# Out:
# (23, 1, 3, 4)

# %%
test9(2,5,a=2342)
# Out:
# (2342, 1, 2, 5)

# %%
def add(a,b):
  return a+b
def sub(a,b):
  return a-b

# %%
add(5,8)
# Out:
# 13

# %%
def calc(a,b,p):
  if p == "+":
   print (a+b)
  elif p == "-":
    print(a-b)
  elif p == "*":
      print(a*b)
  elif p == "/":
        print(a/b)
  return "done"

n1=int(input("enter first number="))
n2=int(input("enter second number="))
op=input("enter operator")
calc(n1,n2,op)
# Out:
# enter first number=87
# enter second number=10
# enter operator-
# 77
# 'done'

# %%
def calc(a,b,p):
  if p == "+":
   print (a+b)
  elif p == "-":
    print(a-b)
  elif p == "*":
      print(a*b)
  elif p == "/":
        print(a/b)
  return "done"

n1=int(input("enter first number="))
n2=int(input("enter second number="))
op=input("enter operator")
calc(n1,n2,op)
# Out:
# enter first number=67
# enter second number=10
# enter operator+
# 77
# 'done'

# %%
def calc(a,b,p):
  if p == "+":
   print (a+b)
  elif p == "-":
    print(a-b)
  elif p == "*":
      print(a*b)
  elif p == "/":
        print(a/b)
  return "done"

n1=int(input("enter first number="))
n2=int(input("enter second number="))
op=input("enter operator=")
calc(n1,n2,op)
# Out:
# enter first number=98
# enter second number=100
# enter operator=+
# 198
# 'done'

# %%
account_number=int(input("enter account number="))
balance=int(input("enter balance="))
pin=int(input("enter pin="))
dic={"bank balance":20000,"account_number":1234567,"pin":1234}
if account_number==dic["account_number"] and pin==dic["pin"]:
  print("your card is valid")
  print("1-bank balance")
  print("2-cash withdrawal")
  print("3-deposit")
  print("4-exit")
  choice=int(input("enter your choice="))
  if choice==1:
    print("your bank balance is=",dic["bank balance"])
  elif choice==2:
      amount=int(input("enter amount="))
  if amount<=balance:
    balance= balance-amount
    print("your balance is=",balance)
  else:
    print("insufficient balance")
# Out:
# enter account number=1234567
# enter balance=10000
# enter pin=1234
# your card is valid
# 1-bank balance
# 2-cash withdrawal
# 3-deposit
# 4-exit
# enter your choice=1
# your bank balance is= 20000
# your balance is= 5500

# %%
Options=["Balance","Withdraw","Change pin","Exit"]
print("Welcome to services")
print("please insert your card")
print("your card is inserted")

if input("Enter the pin: ")=="1234":
  print("Your pin is accepted")

  for i in Options:
    print(i)
    Services=int(input("Select your option: "))
    if Services==1:
      print("Your balance is: 10000")
    elif Services==2:
      Withdraw= int(input("Please enter amount: "))
      print(f"you have withdrawn: {Withdraw}")
    elif Services==3:
        New_Pin_val = input("Please enter new pin: ")
        print(f"Your pin has been changed to: {New_Pin_val}")
    elif Services==4:
          print("Thank you for using our services")
    else:
            print("invalid option selected")
else:
  print("invalid pin")
# Out:
# Welcome to services
# please insert your card
# your card is inserted
# Enter the pin: 1234
# Your pin is accepted
# Balance
# Select your option: 2
# Please enter amount: 2000
# you have withdrawn: 2000
# Withdraw
# Select your option: 2
# Please enter amount: 5000
# you have withdrawn: 5000
# Change pin
# Select your option: 273927
# invalid option selected
# Exit
# Select your option: 3
# Please enter new pin: 0987
# Your pin has been changed to: 0987
