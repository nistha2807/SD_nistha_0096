# %% [markdown]
# <a href="https://colab.research.google.com/github/nistha2807/SD_nistha_0096/blob/main/TYPE_CONVERSION_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
q=[2,3,"jeni",True,9.5]

# %%
s="my name is jeni"

# %%
q+[s]
# Out:
# [2, 3, 'jeni', True, 9.5, 'my name is jeni']

# %%
list(s)+q
# Out:
# ['m',
#  'y',
#  ' ',
#  'n',
#  'a',
#  'm',
#  'e',
#  ' ',
#  'i',
#  's',
#  ' ',
#  'j',
#  'e',
#  'n',
#  'i',
#  2,
#  3,
#  'jeni',
#  True,
#  9.5]

# %%
q.insert(2,'28')

# %%
q
# Out:
# [2, 3, '28', '28', 'jeni', True, 9.5]

# %%
q.pop(2)
# Out:
# '28'

# %%
q
# Out:
# [2, 3, 'jeni', True, 9.5]

# %%
a = input()
# Out:
# 20

# %%
print("a",a)
# Out:
# a 20

# %%
b = input()
# Out:
# nistha

# %%
print("name:",b)
# Out:
# name: nistha

# %%
age = int(input("Enter age:"))
# Out:
# Enter age:20

# %%
print("Age:",age)
# Out:
# Age: 20

# %%
x="10"

# %%
y=int(x)

# %%
print(y)
# Out:
# 10

# %%
x="3.14"

# %%
y=float(x)

# %%
print(y)
# Out:
# 3.14

# %%
x=25

# %%
y=str(x)

# %%
print(y)
# Out:
# 25

# %%
x=(1,2,3)
y=list(x)
print(y)
# Out:
# [1, 2, 3]

# %%
x=(1,2,3)
y=list(x)
print(y)
# Out:
# [1, 2, 3]

# %%
x=(1,2,2,3)
y=set(x)
print(y)
# Out:
# {1, 2, 3}

# %%
x=3.14

# %%
y=int(x)

# %%
print(y)
# Out:
# 3

# %%
x=25
y=str(x)
print(y)
# Out:
# 25
