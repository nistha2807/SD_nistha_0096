# %% [markdown]
# <a href="https://colab.research.google.com/github/nistha2807/SD_nistha_0096/blob/main/CONDITIONAL_CONTROL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x = 10
if (x > 5):
    print("x is greater than 5")
# Out:
# x is greater than 5

# %%
x=3
if x%2 == 0:
  print("x is even")
else:
  print("x is odd")
# Out:
# x is odd
