# %% [markdown]
# <a href="https://colab.research.google.com/github/nistha2807/SD_nistha_0096/blob/main/LIST.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nums = [1,2,3,4]

# %%
nums[0]
# Out:
# 1

# %%
nums[2]
# Out:
# 3

# %%
nums[1]
# Out:
# 2

# %%
type[list]
# Out:
# type[[0, 2, 4, 6, 8]]

# %%
list=[56,"nistha",9.8]

# %%
list[0]
# Out:
# 56

# %%
nis=[56,78,54,"nistha","palak","kavya",7.8,9.7,4.5,3.4]

# %%
nis[3][0:1]
# Out:
# 'n'

# %%
nis[3][0:2]
# Out:
# 'ni'

# %%
nis.append(True)

# %%
nis
# Out:
# [56, 78, 54, 'nistha', 'palak', 'kavya', 7.8, 9.7, 4.5, 3.4, True, True]

# %%
str(nis[10])[0:2]
# Out:
# 'Tr'

# %%
list_from_string = [char for char in s]
display(list_from_string)

# %%
s="my name is jeni"

# %%
list(s)+nis
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1555/29089338.py in <cell line: 0>()
# ----> 1 list(s)+nis
#
# TypeError: 'list' object is not callable
